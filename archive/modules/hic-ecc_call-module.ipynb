# %% [markdown]
# # HiC-ECC | Module 3: Call
# Loop and TAD calling on enhanced `.cool` files.

# %% [markdown]
# ## Config
# **Edit only this cell.**

# %%
#Paths
COOL_DIR = "/path/to/cool_files"   # folder containing per-tissue subfolders
OUT_DIR  = "/path/to/output"       # where results will be saved

#Tissues
TISSUES = [
    "Brain",
    "Kidney",
    "Large_Intestine",
    "Liver",
    "Lung",
    "Pancreas",
    "Small_Intestine",
    "Spleen",
]

#File naming
# Input cool files are expected at: COOL_DIR/{tissue}/{tissue}_deephic.10kb.cool
COOL_SUFFIX = "_deephic.10kb.cool"   # change if using a different enhancer
THREADS = 12

# %% [markdown]
# ## Setup

# %%
import os, subprocess

os.makedirs(OUT_DIR, exist_ok=True)
print("Output directory ready:", OUT_DIR)

# %% [markdown]
# ## Loop Calling (Chromosight)

# %%
for tissue in TISSUES:
    cool = f"{COOL_DIR}/{tissue}/{tissue}{COOL_SUFFIX}"
    out  = f"{OUT_DIR}/{tissue}_loops"

    if not os.path.isfile(cool):
        print(f"[SKIP] Missing file: {cool}")
        continue

    print(f"[loops] {tissue}")
    subprocess.run(
        ["chromosight", "detect", "-t", str(THREADS), cool, out],
        check=True
    )

print("Loop calling done.")

# %% [markdown]
# ## TAD Calling (hicFindTADs)

# %%
for tissue in TISSUES:
    cool   = f"{COOL_DIR}/{tissue}/{tissue}{COOL_SUFFIX}"
    prefix = f"{OUT_DIR}/{tissue}_tads"

    if not os.path.isfile(cool):
        print(f"[SKIP] Missing file: {cool}")
        continue

    print(f"[TADs] {tissue}")
    subprocess.run(
        ["hicFindTADs", "-m", cool,
         "--outPrefix", prefix,
         "--correctForMultipleTesting", "fdr"],
        check=True
    )

print("TAD calling done.")
